# %% [markdown]
# <a href="https://colab.research.google.com/github/EkansTCG/AI-hw-2/blob/main/Next_Word_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import torch

# Load model
print("Loading AI model...")
model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# Loading AI model...

# %%
# Simple example
text = "The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking"
print(f"\nStarting text: '{text}'")
print("\nGenerating word by word...\n")

# Generate 30 words, one at a time
current_text = text
for step in range(30):
    print(f"--- Step {step + 1} ---")
    print(f"Current: '{current_text}'")

    # Encode current text
    input_ids = tokenizer.encode(current_text, return_tensors="pt")

    # Get predictions
    with torch.no_grad():
        outputs = model(input_ids)
        predictions = outputs.logits

    # Get the predictions for the NEXT token
    next_token_logits = predictions[0, -1, :]
    next_token_probs = torch.softmax(next_token_logits, dim=0)

    # Get top 5 predictions for display purposes
    # This line fixes the error you were seeing in your loop
    top_probs, top_indices = torch.topk(next_token_probs, 5)

    print("Top 5 next word predictions:")
    for i, (prob, idx) in enumerate(zip(top_probs, top_indices)):
        word = tokenizer.decode([idx])
        print(f"  {i+1}. '{word}' ({prob.item() * 100:.1f}% confident)")

    # Pick the next token using the GREEDY strategy (highest probability)
    next_token_id = torch.argmax(next_token_probs, dim=-1)
    next_word = tokenizer.decode([next_token_id])

    # Append to text
    current_text += next_word
    print(f"✓ Chosen: '{next_word}'")
    print(f"New text: '{current_text}'\n")

print(f"\nFinal generated text: '{current_text}'")
# Out:
# Starting text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking'
#
# Generating word by word...
#
# --- Step 1 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking'
# Top 5 next word predictions:
#   1. ' the' (17.3% confident)
#   2. ' up' (10.3% confident)
#   3. ' No' (5.1% confident)
#   4. ' a' (4.8% confident)
#   5. ' out' (3.0% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the'
#
# --- Step 2 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the'
# Top 5 next word predictions:
#   1. ' 49' (6.0% confident)
#   2. ' Packers' (5.9% confident)
#   3. ' first' (5.5% confident)
#   4. ' second' (3.7% confident)
#   5. ' No' (3.6% confident)
# ✓ Chosen: ' 49'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49'
#
# --- Step 3 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49'
# Top 5 next word predictions:
#   1. 'ers' (99.5% confident)
#   2. 'er' (0.5% confident)
#   3. 'th' (0.0% confident)
#   4. 'ERS' (0.0% confident)
#   5. '-' (0.0% confident)
# ✓ Chosen: 'ers'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers'
#
# --- Step 4 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers'
# Top 5 next word predictions:
#   1. ' at' (30.1% confident)
#   2. '.' (11.1% confident)
#   3. ' in' (9.3% confident)
#   4. ''' (5.0% confident)
#   5. ',' (4.8% confident)
# ✓ Chosen: ' at'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at'
#
# --- Step 5 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at'
# Top 5 next word predictions:
#   1. ' the' (67.6% confident)
#   2. ' No' (14.3% confident)
#   3. ' number' (1.3% confident)
#   4. ' their' (1.2% confident)
#   5. ' a' (1.1% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the'
#
# --- Step 6 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the'
# Top 5 next word predictions:
#   1. ' end' (85.4% confident)
#   2. ' beginning' (1.2% confident)
#   3. ' top' (1.1% confident)
#   4. ' start' (1.0% confident)
#   5. ' very' (0.9% confident)
# ✓ Chosen: ' end'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end'
#
# --- Step 7 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end'
# Top 5 next word predictions:
#   1. ' of' (99.7% confident)
#   2. '.' (0.1% confident)
#   3. ',' (0.0% confident)
#   4. ' and' (0.0% confident)
#   5. ' the' (0.0% confident)
# ✓ Chosen: ' of'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of'
#
# --- Step 8 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of'
# Top 5 next word predictions:
#   1. ' the' (81.4% confident)
#   2. ' their' (6.4% confident)
#   3. ' last' (3.1% confident)
#   4. ' this' (1.6% confident)
#   5. ' a' (1.4% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the'
#
# --- Step 9 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the'
# Top 5 next word predictions:
#   1. ' first' (59.9% confident)
#   2. ' second' (14.0% confident)
#   3. ' third' (4.4% confident)
#   4. ' fourth' (3.0% confident)
#   5. ' fifth' (1.7% confident)
# ✓ Chosen: ' first'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first'
#
# --- Step 10 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first'
# Top 5 next word predictions:
#   1. ' round' (99.7% confident)
#   2. ' draft' (0.0% confident)
#   3. ' year' (0.0% confident)
#   4. ' and' (0.0% confident)
#   5. '-' (0.0% confident)
# ✓ Chosen: ' round'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round'
#
# --- Step 11 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round'
# Top 5 next word predictions:
#   1. ' of' (89.8% confident)
#   2. '.' (6.7% confident)
#   3. ',' (1.5% confident)
#   4. ' and' (0.4% confident)
#   5. ' in' (0.3% confident)
# ✓ Chosen: ' of'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of'
#
# --- Step 12 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of'
# Top 5 next word predictions:
#   1. ' the' (99.0% confident)
#   2. ' this' (0.2% confident)
#   3. ' their' (0.2% confident)
#   4. ' NFL' (0.1% confident)
#   5. ' a' (0.1% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the'
#
# --- Step 13 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the'
# Top 5 next word predictions:
#   1. ' NFL' (97.1% confident)
#   2. ' league' (0.8% confident)
#   3. ' draft' (0.7% confident)
#   4. ' NBA' (0.2% confident)
#   5. ' 2017' (0.1% confident)
# ✓ Chosen: ' NFL'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL'
#
# --- Step 14 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL'
# Top 5 next word predictions:
#   1. ' draft' (99.3% confident)
#   2. ' Draft' (0.7% confident)
#   3. ' round' (0.0% confident)
#   4. ' trade' (0.0% confident)
#   5. ' pick' (0.0% confident)
# ✓ Chosen: ' draft'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft'
#
# --- Step 15 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft'
# Top 5 next word predictions:
#   1. ',' (62.8% confident)
#   2. '.' (30.8% confident)
#   3. ' in' (1.0% confident)
#   4. ' and' (1.0% confident)
#   5. ' on' (0.4% confident)
# ✓ Chosen: ','
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft,'
#
# --- Step 16 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft,'
# Top 5 next word predictions:
#   1. ' picking' (57.7% confident)
#   2. ' and' (8.7% confident)
#   3. ' pick' (5.7% confident)
#   4. ' selecting' (3.5% confident)
#   5. ' choosing' (2.3% confident)
# ✓ Chosen: ' picking'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking'
#
# --- Step 17 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking'
# Top 5 next word predictions:
#   1. ' the' (98.8% confident)
#   2. ' them' (0.4% confident)
#   3. ' a' (0.1% confident)
#   4. ' their' (0.1% confident)
#   5. ' at' (0.1% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the'
#
# --- Step 18 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the'
# Top 5 next word predictions:
#   1. ' 49' (96.1% confident)
#   2. ' Seahawks' (0.3% confident)
#   3. ' Packers' (0.3% confident)
#   4. ' Steelers' (0.2% confident)
#   5. ' Texans' (0.2% confident)
# ✓ Chosen: ' 49'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49'
#
# --- Step 19 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49'
# Top 5 next word predictions:
#   1. 'ers' (99.8% confident)
#   2. 'er' (0.1% confident)
#   3. 'ERS' (0.1% confident)
#   4. 'ing' (0.0% confident)
#   5. 's' (0.0% confident)
# ✓ Chosen: 'ers'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers'
#
# --- Step 20 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers'
# Top 5 next word predictions:
#   1. ' at' (100.0% confident)
#   2. ' in' (0.0% confident)
#   3. ' on' (0.0% confident)
#   4. ' with' (0.0% confident)
#   5. ' and' (0.0% confident)
# ✓ Chosen: ' at'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at'
#
# --- Step 21 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at'
# Top 5 next word predictions:
#   1. ' the' (99.9% confident)
#   2. ' a' (0.0% confident)
#   3. ' their' (0.0% confident)
#   4. ' The' (0.0% confident)
#   5. ' that' (0.0% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the'
#
# --- Step 22 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the'
# Top 5 next word predictions:
#   1. ' end' (99.8% confident)
#   2. ' start' (0.0% confident)
#   3. ' beginning' (0.0% confident)
#   4. ' ends' (0.0% confident)
#   5. ' End' (0.0% confident)
# ✓ Chosen: ' end'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end'
#
# --- Step 23 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end'
# Top 5 next word predictions:
#   1. ' of' (99.9% confident)
#   2. '
# ' (0.0% confident)
#   3. '.' (0.0% confident)
#   4. ',' (0.0% confident)
#   5. ' (' (0.0% confident)
# ✓ Chosen: ' of'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of'
#
# --- Step 24 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of'
# Top 5 next word predictions:
#   1. ' the' (99.8% confident)
#   2. ' a' (0.1% confident)
#   3. ' this' (0.0% confident)
#   4. ' their' (0.0% confident)
#   5. ' that' (0.0% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the'
#
# --- Step 25 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the'
# Top 5 next word predictions:
#   1. ' first' (99.1% confident)
#   2. ' second' (0.3% confident)
#   3. ' last' (0.2% confident)
#   4. ' 1' (0.2% confident)
#   5. ' First' (0.0% confident)
# ✓ Chosen: ' first'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first'
#
# --- Step 26 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first'
# Top 5 next word predictions:
#   1. ' round' (99.9% confident)
#   2. ' day' (0.0% confident)
#   3. ' year' (0.0% confident)
#   4. ' draft' (0.0% confident)
#   5. ' level' (0.0% confident)
# ✓ Chosen: ' round'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round'
#
# --- Step 27 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round'
# Top 5 next word predictions:
#   1. ' of' (99.9% confident)
#   2. '.' (0.0% confident)
#   3. ',' (0.0% confident)
#   4. '
# ' (0.0% confident)
#   5. ' (' (0.0% confident)
# ✓ Chosen: ' of'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of'
#
# --- Step 28 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of'
# Top 5 next word predictions:
#   1. ' the' (99.8% confident)
#   2. ' a' (0.0% confident)
#   3. ' this' (0.0% confident)
#   4. ' The' (0.0% confident)
#   5. ' NFL' (0.0% confident)
# ✓ Chosen: ' the'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the'
#
# --- Step 29 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the'
# Top 5 next word predictions:
#   1. ' NFL' (99.8% confident)
#   2. ' league' (0.1% confident)
#   3. ' NBA' (0.0% confident)
#   4. ' NHL' (0.0% confident)
#   5. ' 2017' (0.0% confident)
# ✓ Chosen: ' NFL'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL'
#
# --- Step 30 ---
# Current: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL'
# Top 5 next word predictions:
#   1. ' draft' (99.9% confident)
#   2. ' Draft' (0.1% confident)
#   3. ' round' (0.0% confident)
#   4. ' pick' (0.0% confident)
#   5. ' trade' (0.0% confident)
# ✓ Chosen: ' draft'
# New text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft'
#
#
# Final generated text: 'The Green Bay Packers were up to make their pick at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft, picking the 49ers at the end of the first round of the NFL draft'
